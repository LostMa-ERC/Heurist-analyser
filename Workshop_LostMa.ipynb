# %% [markdown]
# Welcome to the Lostma Workshop!
#
# This Notebook aims to explore the data collected as part of the project and manipulate it together.
#
# The data itself is available on [Heurist](https://heurist.huma-num.fr/heurist/?db=jbcamps_gestes) and the schema is described on the [website](https://lostma-erc.github.io/corpus/documentation)
#
# # **I) Notebook setup**
#
# To use this notebook, you first need to download the library created in order to facilitate exploration of our Heurist Database. This tool is based on the [Heurist-API](https://pypi.org/project/heurist-api) developped by Kelly Christensen. Thanks to this API, we can extract, transform and load the content of an Heurist database into a DuckDB database making it easier to use queries with SQL. We then created a specific LostMa Python object to help us to explore the content of the data.
#
# So please, start with installation:

# %%
# !pip install "git+https://github.com/LostMa-ERC/Heurist-analyser.git"
# Out:
# Collecting git+https://github.com/LostMa-ERC/Heurist-analyser.git
#   Cloning https://github.com/LostMa-ERC/Heurist-analyser.git to /tmp/pip-req-build-4501u0r6
#   Running command git clone --filter=blob:none --quiet https://github.com/LostMa-ERC/Heurist-analyser.git /tmp/pip-req-build-4501u0r6
#   Resolved https://github.com/LostMa-ERC/Heurist-analyser.git to commit abba05a4f7b622af8720bcb3a1a5290c72643eee
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting heurist-api<0.3.0,>=0.2.5 (from heurist-analyser==0.1.0)
#   Downloading heurist_api-0.2.5-py3-none-any.whl.metadata (27 kB)
# Collecting duckdb<2.0.0,>=1.4.1 (from heurist-analyser==0.1.0)
#   Downloading duckdb-1.4.2-cp312-cp312-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl.metadata (4.3 kB)
# Requirement already satisfied: click>=8.2.0 in /usr/local/lib/python3.12/dist-packages (from heurist-api<0.3.0,>=0.2.5->heurist-analyser==0.1.0) (8.3.1)
# Requirement already satisfied: lxml>=5.4.0 in /usr/local/lib/python3.12/dist-packages (from heurist-api<0.3.0,>=0.2.5->heurist-analyser==0.1.0) (6.0.2)
# Collecting pandas>=2.2.3 (from heurist-api<0.3.0,>=0.2.5->heurist-analyser==0.1.0)
#   Downloading pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: polars>=1.29.0 in /usr/local/lib/python3.12/dist-packages (from heurist-api<0.3.0,>=0.2.5->heurist-analyser==0.1.0) (1.31.0)
# Collecting pyarrow>=20.0.0 (from heurist-api<0.3.0,>=0.2.5->heurist-analyser==0.1.0)
#   Downloading pyarrow-22.0.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.2 kB)
# Collecting pydantic-xml<2.17.0,>=2.16.0 (from heurist-api<0.3.0,>=0.2.5->heurist-analyser==0.1.0)
#   Downloading pydantic_xml-2.16.0-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: pydantic>=2.11.4 in /usr/local/lib/python3.12/dist-packages (from heurist-api<0.3.0,>=0.2.5->heurist-analyser==0.1.0) (2.12.3)
# Requirement already satisfied: python-dotenv>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from heurist-api<0.3.0,>=0.2.5->heurist-analyser==0.1.0) (1.2.1)
# Requirement already satisfied: requests>=2.32.3 in /usr/local/lib/python3.12/dist-packages (from heurist-api<0.3.0,>=0.2.5->heurist-analyser==0.1.0) (2.32.4)
# Collecting rich>=14.0.0 (from heurist-api<0.3.0,>=0.2.5->heurist-analyser==0.1.0)
#   Downloading rich-14.2.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: tenacity>=9.1.2 in /usr/local/lib/python3.12/dist-packages (from heurist-api<0.3.0,>=0.2.5->heurist-analyser==0.1.0) (9.1.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.3->heurist-api<0.3.0,>=0.2.5->heurist-analyser==0.1.0) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.3->heurist-api<0.3.0,>=0.2.5->heurist-analyser==0.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.3->heurist-api<0.3.0,>=0.2.5->heurist-analyser==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.2.3->heurist-api<0.3.0,>=0.2.5->heurist-analyser==0.1.0) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.4->heurist-api<0.3.0,>=0.2.5->heurist-analyser==0.1.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.4->heurist-api<0.3.0,>=0.2.5->heurist-analyser==0.1.0) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.4->heurist-api<0.3.0,>=0.2.5->heurist-analyser==0.1.0) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.4->heurist-api<0.3.0,>=0.2.5->heurist-analyser==0.1.0) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.3->heurist-api<0.3.0,>=0.2.5->heurist-analyser==0.1.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.3->heurist-api<0.3.0,>=0.2.5->heurist-analyser==0.1.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.3->heurist-api<0.3.0,>=0.2.5->heurist-analyser==0.1.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.3->heurist-api<0.3.0,>=0.2.5->heurist-analyser==0.1.0) (2025.11.12)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=14.0.0->heurist-api<0.3.0,>=0.2.5->heurist-analyser==0.1.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=14.0.0->heurist-api<0.3.0,>=0.2.5->heurist-analyser==0.1.0) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=14.0.0->heurist-api<0.3.0,>=0.2.5->heurist-analyser==0.1.0) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.2.3->heurist-api<0.3.0,>=0.2.5->heurist-analyser==0.1.0) (1.17.0)
# Downloading duckdb-1.4.2-cp312-cp312-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl (20.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.5/20.5 MB 82.7 MB/s eta 0:00:00
# Downloading heurist_api-0.2.5-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.1/101.1 kB 9.3 MB/s eta 0:00:00
# Downloading pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 111.0 MB/s eta 0:00:00
# Downloading pyarrow-22.0.0-cp312-cp312-manylinux_2_28_x86_64.whl (47.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 MB 13.5 MB/s eta 0:00:00
# Downloading pydantic_xml-2.16.0-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 kB 2.7 MB/s eta 0:00:00
# Downloading rich-14.2.0-py3-none-any.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.4/243.4 kB 20.5 MB/s eta 0:00:00
# Building wheels for collected packages: heurist-analyser
#   Building wheel for heurist-analyser (pyproject.toml) ... done
#   Created wheel for heurist-analyser: filename=heurist_analyser-0.1.0-py3-none-any.whl size=10218 sha256=ffab530a5b5dd583dfce10ab8aa1fa46aef001d316a2b7250f70fedcda991725
#   Stored in directory: /tmp/pip-ephem-wheel-cache-p2qeeng7/wheels/8e/0c/2d/c05af6ba9fcf222df52689074f805b00851095f133dc6db8ee
# Successfully built heurist-analyser
# Installing collected packages: pyarrow, duckdb, rich, pandas, pydantic-xml, heurist-api, heurist-analyser
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 18.1.0
#     Uninstalling pyarrow-18.1.0:
#       Successfully uninstalled pyarrow-18.1.0
#   Attempting uninstall: duckdb
#     Found existing installation: duckdb 1.3.2
#     Uninstalling duckdb-1.3.2:
#       Successfully uninstalled duckdb-1.3.2
#   Attempting uninstall: rich
#     Found existing installation: rich 13.9.4
#     Uninstalling rich-13.9.4:
#       Successfully uninstalled rich-13.9.4
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# bigframes 2.29.1 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# Successfully installed duckdb-1.4.2 heurist-analyser-0.1.0 heurist-api-0.2.5 pandas-2.3.3 pyarrow-22.0.0 pydantic-xml-2.16.0 rich-14.2.0

# %% [markdown]
# You can then use your Heurist login details to download the Lostma database:

# %%
from lostma_db import LostmaDB

login = "your login"
pwd = "your password"
db = LostmaDB(login, pwd)

# %%
db.sync()

# %% [markdown]
# # **II) Data access**
#
# It is now possible to access the contents of tables (for example, the witness table here) with SQL queries:

# %%
db.sql("SELECT * FROM witness")
# Out:
#        H-ID  type_id  is_manifestation_of H-ID observed_on_pages H-ID  \
# 0     54257      105                     586.0                [52507]
# 1     55200      105                   48907.0                [51255]
# 2     53697      105                   48859.0                [51238]
# 3     53719      105                     773.0                [52713]
# 4     54247      105                   50237.0                [52196]
# ...     ...      ...                       ...                    ...
# 2561  48051      105                   48049.0                [48052]
# 2562  47458      105                   47293.0                [47459]
# 2563  47454      105                   47293.0                [47455]
# 2564  47433      105                   46322.0                [47434]
# 2565  47420      105                   47369.0         [47421, 55766]
#
#       last_observed_in_doc H-ID is_unobserved  is_unobserved TRM-ID  \
# 0                           NaN            No                  9483
# 1                           NaN            No                  9483
# 2                           NaN            No                  9483
# 3                           NaN            No                  9483
# 4                           NaN            No                  9483
# ...                         ...           ...                   ...
# 2561                        NaN            No                  9483
# 2562                    47457.0            No                  9483
# 2563                    47453.0            No                  9483
# 2564                    47432.0            No                  9483
# 2565                    47419.0            No                  9483
#
#       claim_freetext  used_to_follow_fragment H-ID  \
# 0               <NA>                          <NA>
# 1               <NA>                          <NA>
# 2               <NA>                          <NA>
# 3               <NA>                          <NA>
# 4               <NA>                          <NA>
# ...              ...                           ...
# 2561            <NA>                          <NA>
# 2562            <NA>                          <NA>
# 2563            <NA>                          <NA>
# 2564            <NA>                          <NA>
# 2565            <NA>                          <NA>
#
#       used_to_follow_witness H-ID  ... number_of_hands scribe_note  \
# 0                            <NA>  ...             NaN        None
# 1                            <NA>  ...             NaN        None
# 2                            <NA>  ...             NaN        None
# 3                            <NA>  ...             NaN        None
# 4                            <NA>  ...             NaN        None
# ...                           ...  ...             ...         ...
# 2561                         <NA>  ...             NaN        None
# 2562                         <NA>  ...             NaN        None
# 2563                         <NA>  ...             NaN        None
# 2564                         <NA>  ...             NaN        None
# 2565                         <NA>  ...             NaN        None
#
#      place_of_creation H-ID  place_of_creation_source  \
# 0                        []                      None
# 1                        []                      None
# 2                        []                      None
# 3                        []                      None
# 4                        []                      None
# ...                     ...                       ...
# 2561                     []                      None
# 2562                     []                      None
# 2563                     []                      None
# 2564                     []                      None
# 2565                     []                      None
#
#      described_by_source H-ID  \
# 0                          []
# 1                          []
# 2                          []
# 3                          []
# 4                          []
# ...                       ...
# 2561                  [47483]
# 2562                       []
# 2563                       []
# 2564                       []
# 2565                       []
#
#                                        described_at_URL  \
# 0     [http://jonas.irht.cnrs.fr/manuscrit/72901, ht...
# 1     [http://jonas.irht.cnrs.fr/manuscrit/73408, ht...
# 2     [http://jonas.irht.cnrs.fr/manuscrit/45508, ht...
# 3     [http://jonas.irht.cnrs.fr/manuscrit/59028, ht...
# 4     [http://jonas.irht.cnrs.fr/manuscrit/45517, ht...
# ...                                                 ...
# 2561  [https://www.arlima.net/eh/huon_de_bordeaux/nl...
# 2562         [https://www.handschriftencensus.de/18870]
# 2563                                                 []
# 2564                                                 []
# 2565         [https://www.handschriftencensus.de/20260]
#
#                           reference_notes    review_status  \
# 0                                      []             Open
# 1                                      []  Action required
# 2                                      []  Action required
# 3     [Concaténé avec Huon de Bordeaux ?]  Action required
# 4                                      []  Action required
# ...                                   ...              ...
# 2561                                   []  Action required
# 2562                                   []  Action required
# 2563                                   []  Action required
# 2564                                   []  Action required
# 2565                                   []             Open
#
#      review_status TRM-ID                                        review_note
# 0                    9698  92:The status was marked as a citation or extr...
# 1                    9697  198:The status was marked as a citation or ext...
# 2                    9697  443:The status was marked as a citation or ext...
# 3                    9697  462:The status was marked as a citation or ext...
# 4                    9697  911:The status was marked as a citation or ext...
# ...                   ...                                                ...
# 2561                 9697                             Kienhorst zegt in BNM?
# 2562                 9697                                               Ref.
# 2563                 9697                                               Ref.
# 2564                 9697                                        Check, ref.
# 2565                 9698                                               None
#
# [2566 rows x 35 columns]

# %% [markdown]
# NB: If you know [SQL](https://www.w3schools.com/sql/), you can use the [data model](https://github.com/LostMa-ERC/DataArchitect2025/blob/main/heurist.jpg) to extract all the data you want to see as a dataframe
#
# To help you, we created some pre-defined queries to explore the most usefull data (we recommend limiting the scope to ready-to-use language corpora)

# %%
available_languages = ["dum (Middle Dutch)", "enm (Middle English)", "fro (Old French)", "frm (Middle French)"]

# %%
db.texts(available_languages)
# Out:
#       H-ID  type_id                 preferred_name     language_COLUMN  \
# 0    47788      101           Willem van Oringen I  dum (Middle Dutch)
# 1    55292      101           Alexander-compilatie  dum (Middle Dutch)
# 2    48337      101                      Aspremont  dum (Middle Dutch)
# 3    47903      101            Aubri de Borgengoen  dum (Middle Dutch)
# 4    47529      101            Barlaam en Josaphat  dum (Middle Dutch)
# ..     ...      ...                            ...                 ...
# 512  48714      101              Apollonius de Tyr    fro (Old French)
# 513  49488      101  Departement des enfans Aimeri    fro (Old French)
# 514  48529      101                          Eneas    fro (Old French)
# 515  48814      101               L'âtre périlleux    fro (Old French)
# 516  48912      101             Le roman de Balain    fro (Old French)
#
#      language_COLUMN TRM-ID literary_form  literary_form TRM-ID  \
# 0                    9728.0         verse                9549.0
# 1                    9728.0         verse                9549.0
# 2                    9728.0         verse                9549.0
# 3                    9728.0         verse                9549.0
# 4                    9728.0         verse                9549.0
# ..                      ...           ...                   ...
# 512                  9470.0         prose                9550.0
# 513                  9470.0         verse                9549.0
# 514                  9470.0         prose                9550.0
# 515                  9470.0         verse                9549.0
# 516                  9470.0         prose                9550.0
#
#     is_hypothetical  is_hypothetical TRM-ID claim_freetext  ...  \
# 0                No                    9483           None  ...
# 1                No                    9483           None  ...
# 2                No                    9483           None  ...
# 3                No                    9483           None  ...
# 4                No                    9483           None  ...
# ..              ...                     ...            ...  ...
# 512              No                    9483           None  ...
# 513              No                    9483           None  ...
# 514              No                    9483           None  ...
# 515              No                    9483           None  ...
# 516              No                    9483           None  ...
#
#     is_adapted_by H-ID author_freetext place_of_creation H-ID  \
# 0                   []            None                    NaN
# 1                   []            None                    NaN
# 2                   []            None                    NaN
# 3                   []            None                    NaN
# 4                   []            None                    NaN
# ..                 ...             ...                    ...
# 512                 []            None                    NaN
# 513                 []            None                    NaN
# 514                 []            None                    NaN
# 515                 []            None                    NaN
# 516                 []            None                    NaN
#
#      place_of_creation_source      described_by_source H-ID  \
# 0                        None  [47485, 47482, 47484, 47483]
# 1                        None                            []
# 2                        None                [47485, 47483]
# 3                        None  [47485, 47482, 47484, 47483]
# 4                        None                       [47485]
# ..                        ...                           ...
# 512                      None                            []
# 513                      None                            []
# 514                      None                            []
# 515                      None                            []
# 516                      None                            []
#
#                                       described_at_URL  \
# 0       [https://lib.ugent.be/catalog/rug01:000990047]
# 1                                                   []
# 2                                                   []
# 3           [https://www.handschriftencensus.de/20269]
# 4                                                   []
# ..                                                 ...
# 512  [https://arlima.net/no/12079, http://jonas.irh...
# 513  [https://arlima.net/no/13731, http://jonas.irh...
# 514           [http://jonas.irht.cnrs.fr/oeuvre/13086]
# 515  [http://jonas.irht.cnrs.fr/oeuvre/5641, https:...
# 516                        [https://arlima.net/no/787]
#
#                               reference_notes    review_status  \
# 0                                          []             Open
# 1                                          []  Action required
# 2                                          []             Open
# 3                                          []             Open
# 4                                          []             Open
# ..                                        ...              ...
# 512  [ARLIMA: 361, https://arlima.net/no/361]             Open
# 513                           [JONAS : 13731]             Open
# 514                                        []             Open
# 515                                        []             Open
# 516  [ARLIMA: 787, https://arlima.net/no/787]  Action required
#
#     review_status TRM-ID                                        review_note
# 0                 9698.0                                               None
# 1                 9697.0  Schoenaers, Breeus-Loos, Katz, and Sleiderink ...
# 2                 9698.0                                               None
# 3                 9698.0                                               None
# 4                 9698.0                                               None
# ..                   ...                                                ...
# 512               9698.0  The story of Apollonius of Tyre has not yet be...
# 513               9698.0                                               None
# 514               9698.0                                               None
# 515               9698.0                                               None
# 516               9697.0  It is listed as part of the Brittany material ...
#
# [517 rows x 52 columns]

# %%
db.witnesses(available_languages)
# Out:
#        H-ID  type_id  is_manifestation_of H-ID observed_on_pages H-ID  \
# 0     54257      105                     586.0                [52507]
# 1     55200      105                   48907.0                [51255]
# 2     53697      105                   48859.0                [51238]
# 3     53719      105                     773.0                [52713]
# 4     54246      105                   50237.0                [52193]
# ...     ...      ...                       ...                    ...
# 2628  53436      105                   48765.0                [51121]
# 2629  53428      105                   48765.0                [51113]
# 2630  53422      105                   48765.0                [51109]
# 2631  53439      105                   48765.0                [51123]
# 2632  53437      105                   48765.0                [51122]
#
#       last_observed_in_doc H-ID is_unobserved  is_unobserved TRM-ID  \
# 0                           NaN            No                  9483
# 1                           NaN            No                  9483
# 2                           NaN            No                  9483
# 3                           NaN            No                  9483
# 4                           NaN            No                  9483
# ...                         ...           ...                   ...
# 2628                        NaN            No                  9483
# 2629                        NaN            No                  9483
# 2630                        NaN            No                  9483
# 2631                        NaN            No                  9483
# 2632                        NaN            No                  9483
#
#       claim_freetext  used_to_follow_fragment H-ID  \
# 0               <NA>                          <NA>
# 1               <NA>                          <NA>
# 2               <NA>                          <NA>
# 3               <NA>                          <NA>
# 4               <NA>                          <NA>
# ...              ...                           ...
# 2628            <NA>                          <NA>
# 2629            <NA>                          <NA>
# 2630            <NA>                          <NA>
# 2631            <NA>                          <NA>
# 2632            <NA>                          <NA>
#
#       used_to_follow_witness H-ID  ... place_of_creation_freetext  \
# 0                            <NA>  ...                       <NA>
# 1                            <NA>  ...                       <NA>
# 2                            <NA>  ...                       <NA>
# 3                            <NA>  ...                       <NA>
# 4                            <NA>  ...                       <NA>
# ...                           ...  ...                        ...
# 2628                         <NA>  ...                       <NA>
# 2629                         <NA>  ...                       <NA>
# 2630                         <NA>  ...                       <NA>
# 2631                         <NA>  ...                       <NA>
# 2632                         <NA>  ...                       <NA>
#
#      place_of_creation_source_2 described_by_source H-ID_2  \
# 0                          <NA>                         []
# 1                          <NA>                         []
# 2                          <NA>                         []
# 3                          <NA>                         []
# 4                          <NA>                         []
# ...                         ...                        ...
# 2628                       <NA>                         []
# 2629                       <NA>                         []
# 2630                       <NA>                         []
# 2631                       <NA>                         []
# 2632                       <NA>                         []
#
#                                      described_at_URL_2  \
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3     [http://jonas.irht.cnrs.fr/manuscrit/59028, ht...
# 4                                                    []
# ...                                                 ...
# 2628        [http://jonas.irht.cnrs.fr/manuscrit/83470]
# 2629        [http://jonas.irht.cnrs.fr/manuscrit/79278]
# 2630                                                 []
# 2631        [http://jonas.irht.cnrs.fr/manuscrit/83225]
# 2632                                                 []
#
#                                    online_catalogue_URL                   ARK  \
# 0     https://archivesetmanuscrits.bnf.fr/ark:/12148...   ark:/12148/cc51045t
# 1     https://archivesetmanuscrits.bnf.fr/ark:/12148...   ark:/12148/cc76887d
# 2     https://archivesetmanuscrits.bnf.fr/ark:/12148...   ark:/12148/cc45158c
# 3                                                  None                  None
# 4     https://archivesetmanuscrits.bnf.fr/ark:/12148...   ark:/12148/cc49846f
# ...                                                 ...                   ...
# 2628  https://archivesetmanuscrits.bnf.fr/ark:/12148...  ark:/12148/cc125661b
# 2629                                               None                  None
# 2630                                               None                  None
# 2631                                               None                  None
# 2632  https://catalog.princeton.edu/catalog/99365845...                  None
#
#       reference_notes_2  review_status_3 review_status TRM-ID_3  \
# 0                    []             Open                   9698
# 1                    []             Open                   9698
# 2                    []             Open                   9698
# 3                    []  Action required                   9697
# 4                    []             Open                   9698
# ...                 ...              ...                    ...
# 2628                 []             Open                   9698
# 2629                 []             Open                   9698
# 2630                 []             Open                   9698
# 2631                 []             Open                   9698
# 2632                 []             Open                   9698
#
#                                           review_note_3
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3     This manuscript has two shelfmarks marked as c...
# 4                                                  None
# ...                                                 ...
# 2628                                               None
# 2629                                               None
# 2630                                               None
# 2631                                               None
# 2632                                               None
#
# [2633 rows x 135 columns]

# %% [markdown]
# NB : The witnesses output contains also the data from the text, part and document tables
#
# All the results of these functions can be donwloaded as a csv file for closer examination:

# %%
db.witnesses(available_languages).to_csv("witnesses.csv")

# %% [markdown]
# # III) **Data visualisation**
#
# Once you get the data you need, you can explore them with dedicated software

# %%
import pandas as pd
import plotly.express as px

# %%
df_texts = db.texts(available_languages)
vc_texts = df_texts["language_COLUMN"].value_counts()
counts_texts = pd.DataFrame({
    "language": vc_texts.index,
    "count": vc_texts.values,
    "source": "texts",
})
df_witnesses = db.witnesses(available_languages)
vc_witnesses = df_witnesses["language_COLUMN"].value_counts()
counts_witnesses = pd.DataFrame({
    "language": vc_witnesses.index,
    "count": vc_witnesses.values,
    "source": "witnesses",
})
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
counts_all = pd.concat([counts_texts, counts_witnesses], ignore_index=True)
fig = px.bar(
    counts_all,
    x="language",
    y="count",
    color="source",
    barmode="group",
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="12365d19-aaf5-4801-aa49-cbe1119cebbc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("12365d19-aaf5-4801-aa49-cbe1119cebbc")) {                    Plotly.newPlot(                        "12365d19-aaf5-4801-aa49-cbe1119cebbc",                        [{"alignmentgroup":"True","hovertemplate":"source=texts\u003cbr\u003elanguage=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"texts","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"texts","offsetgroup":"texts","orientation":"v","showlegend":true,"textposition":"auto","x":["fro (Old French)","frm (Middle French)","dum (Middle Dutch)","enm (Middle English)"],"xaxis":"x","y":[279,91,78,69],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"source=witnesses\u003cbr\u003elanguage=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"witnesses","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"witnesses","offsetgroup":"witnesses","orientation":"v","showlegend":true,"textposition":"auto","x":["fro (Old French)","dum (Middle Dutch)","frm (Middle French)","enm (Middle English)"],"xaxis":"x","y":[1890,306,255,182],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outl ...

# %% [markdown]
# If you want to know the data available for a corpus for a specific table, we created a function to see:
#
# - the "completeness table" of each field
# - the number of "total records" for this scope
# - how many records have the "action required" field open

# %%
db.analyse("document", "frm (Middle French)")['completeness table']
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#                                    field required statement  empty records  \
# 0                      current_shelfmark        recommended              4
# 1   contents_of_record_without_shelfmark           optional            250
# 2                             collection           optional            219
# 3                          location H-ID        recommended              4
# 4                         location_known           required              0
# 5                         location_notes           optional            250
# 6                        is_hypothetical           required              0
# 7                         invented_label        recommended            254
# 8                         claim_freetext        recommended            254
# 9                collection_of_fragments           required              0
# 10                         old_shelfmark        recommended            204
# 11                 digitization_freetext           optional            172
# 12              described_by_source H-ID        recommended            254
# 13                      described_at_URL        recommended            128
# 14                  online_catalogue_URL        recommended             68
# 15                                   ARK        recommended            127
# 16                       reference_notes           optional            253
# 17                         review_status           required              0
# 18                           review_note        recommended            251
#
#     percentage empty
# 0               1.71
# 1             106.84
# 2              93.59
# 3               1.71
# 4               0.00
# 5             106.84
# 6               0.00
# 7             108.55
# 8             108.55
# 9               0.00
# 10             87.18
# 11             73.50
# 12            108.55
# 13             54.70
# 14             29.06
# 15             54.27
# 16            108.12
# 17              0.00
# 18            107.26

# %% [markdown]
# You can then see how the data is distributed within a single field:

# %%
attr_col = "status_witness"

df_witnesses = db.witnesses(available_languages)
vc_attr = df_witnesses[attr_col].value_counts(dropna=False)
counts_attr = pd.DataFrame({
    "value": vc_attr.index,
    "count": vc_attr.values,
})

fig = px.bar(
    counts_attr,
    x="value",
    y="count",
)
fig.update_layout(
    xaxis_title=attr_col,
    yaxis_title="Number of records",
    xaxis_tickangle=-45,
)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="71138a6d-8c53-47a1-90eb-97ae39491d38" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("71138a6d-8c53-47a1-90eb-97ae39491d38")) {                    Plotly.newPlot(                        "71138a6d-8c53-47a1-90eb-97ae39491d38",                        [{"alignmentgroup":"True","hovertemplate":"value=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["complete","fragmentary","defective","citation","lost"],"xaxis":"x","y":[1597,815,182,33,6],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"ou ...

# %%
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3ee73c69-7973-441f-b6b0-622b01ec42b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3ee73c69-7973-441f-b6b0-622b01ec42b2")) {                    Plotly.newPlot(                        "3ee73c69-7973-441f-b6b0-622b01ec42b2",                        [{"alignmentgroup":"True","hovertemplate":"value=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["complete","fragmentary","defective","citation","lost"],"xaxis":"x","y":[1597,815,182,33,6],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"ou ...

# %% [markdown]
# Or how this field is distributed according to language:

# %%
lang_col = "language_COLUMN"

grouped = (
    df_witnesses
    .groupby([lang_col, attr_col])
    .size()
    .reset_index(name="count")
)

fig = px.bar(
    grouped,
    x=lang_col,
    y="count",
    color=attr_col,
    barmode="group"
)

fig.update_layout(
    title=f"Répartition des valeurs de {attr_col} par langue",
    xaxis_title="Langue",
    yaxis_title="Nombre de textes",
    xaxis_tickangle=-45,
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8a3da56c-8ff2-4699-bc86-1b41b2404b9b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8a3da56c-8ff2-4699-bc86-1b41b2404b9b")) {                    Plotly.newPlot(                        "8a3da56c-8ff2-4699-bc86-1b41b2404b9b",                        [{"alignmentgroup":"True","hovertemplate":"status_witness=complete\u003cbr\u003elanguage_COLUMN=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"complete","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"complete","offsetgroup":"complete","orientation":"v","showlegend":true,"textposition":"auto","x":["dum (Middle Dutch)","enm (Middle English)","frm (Middle French)","fro (Old French)"],"xaxis":"x","y":[26,105,225,1241],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"status_witness=defective\u003cbr\u003elanguage_COLUMN=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"defective","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"defective","offsetgroup":"defective","orientation":"v","showlegend":true,"textposition":"auto","x":["dum (Middle Dutch)","enm (Middle English)","frm (Middle French)","fro (Old French)"],"xaxis":"x","y":[2,26,12,142],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"status_witness=fragmentary\u003cbr\u003elanguage_COLUMN=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"fragmentary","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"fragmentary","offsetgroup":"fragmentary","orientation":"v","showlegend":true,"textposition":"auto","x":["dum (Middle Dutch)","enm (Middle English)","frm (Middle French)","fro (Old French)"],"xaxis":"x","y":[272,51,18,474],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"status_witness=lost\u003cbr\u003elanguage_COLUMN=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"lost","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"lost","offsetgroup":"lost","orientation":"v","showlegend":true,"textposition":"auto","x":["dum (Middle Dutch)"],"xaxis":"x","y":[6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"status_witness=citation\u003cbr\u003elanguage_COLUMN=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"citation","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"citation","offsetgroup":"citation","orientation":"v","showlegend":true,"textposition":"auto","x":["fro (Old French)"],"xaxis":"x","y":[33],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.55555555555555 ...
